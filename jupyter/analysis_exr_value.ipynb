# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
DIR = '../../render/210324/exr/'
file = DIR + 'img-%d-%s.exr'

# %%
img = cv2.imread(file%(0, 'diffuse'), -1)

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
np.max(img)
# Out:
# 61.46875

# %%
np.min(img)
# Out:
# 0.0

# %%
tmp = file%(0, 'diffuse')
img_gray = cv2.imread(tmp, 0)

# %%
img_gray.shape
# Out:
# (512, 512)

# %%
np.max(img_gray)
# Out:
# 67

# %%
plt.hist(img.flatten(), bins=30)
plt.ylim(0, 20000)
plt.savefig('hist-exr.png')

# %%
tm = cv2.createTonemap(gamma=2.2)
img_tm = tm.process(img)

# %%
img_tm.shape
# Out:
# (512, 512, 3)

# %%
np.max(img_tm)
# Out:
# 1.0

# %%
plt.hist(img_tm.flatten(), bins=30)
plt.ylim(0, 20000)
plt.savefig('hist-tonemap.png')

# %%
plt.hist(img_tm.flatten()*255, bins=30)
plt.ylim(0, 20000)
plt.savefig('hist-png.png')

# %%
img = cv2.imread(file%(0, 'plastic'), -1)

# %%
plt.hist(img.flatten(), bins=30)
plt.ylim(0, 20000)
# Out:
# (0.0, 20000.0)

# %%
img_tm = tm.process(img)
plt.hist(img_tm.flatten(), bins=30)
plt.ylim(0, 20000)
# Out:
# (0.0, 20000.0)

# %%
img = cv2.imread(file%(0, 'au'), -1)
plt.hist(img.flatten(), bins=30)
plt.ylim(0, 20000)
# Out:
# (0.0, 20000.0)

# %%
img_tm = tm.process(img)
plt.hist(img_tm.flatten(), bins=30)
plt.ylim(0, 20000)
# Out:
# (0.0, 20000.0)
